# %%
import pandas as pd
import os

pd.options.display.max_columns = None

# %%
#FOR PC
#df = pd.read_json(r'C:\Users\Garrett Pinkston\Desktop\TIM147\Project\data\Old\yelp_academic_dataset_business.json',lines=True)

#FOR MAC
df = pd.read_json('/Users/garrettpinkston/TIM147/Project/data/Original/yelp_academic_dataset_business.json',lines=True)

#CHECK RESTAURANT, DROP IF NOT
df['categories'] = df['categories'].str.split(", ").tolist()
def checkRestaurant(categories_list):
    if categories_list is not None:
        if 'Restaurants' in categories_list:
            return True
        else:
            return False

df['is_restaurant'] = df['categories'].apply(checkRestaurant)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150346 entries, 0 to 150345
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   business_id    150346 non-null  object
#  1   name           150346 non-null  object
#  2   address        150346 non-null  object
#  3   city           150346 non-null  object
#  4   state          150346 non-null  object
#  5   postal_code    150346 non-null  object
#  6   latitude       150346 non-null  float64
#  7   longitude      150346 non-null  float64
#  8   stars          150346 non-null  float64
#  9   review_count   150346 non-null  int64
#  10  is_open        150346 non-null  int64
#  11  attributes     136602 non-null  object
#  12  categories     150243 non-null  object
#  13  hours          127123 non-null  object
#  14  is_restaurant  150243 non-null  object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 17.2+ MB

# %%
df = df[df['is_restaurant']==True]
df.head(20)
# Out:
#                business_id                            name  \
# 3   MTSW4McQd7CbVtyjqoe9mw              St Honore Pastries
# 5   CF33F8-E6oudUQ46HnavjQ                  Sonic Drive-In
# 8   k0hlBqXX-Bt0vf1op7Jr1w           Tsevi's Pub And Grill
# 9   bBDDEgkFA1Otx9Lfe7BZUQ                  Sonic Drive-In
# 11  eEOYSgkmpB90uNA7lDOMRA           Vietnamese Food Truck
# 12  il_Ro8jwPlHresjw9EGmBg                         Denny's
# 14  0bPLkL0QhhPO5kt1_EXmNQ            Zio's Italian Market
# 15  MUTTqe8uqyMdBl186RmNeA                        Tuna Bar
# 19  ROeacJQwBeh05Rqg7F6TCg                             BAP
# 20  WKMJwqnfZKsAae75RMP6jA  Roast Coffeehouse and Wine Bar
# 22  kfNv-JZpuN6TVNSO6hHdkw                 Hibachi Express
# 23  9OG5YkX1g2GReZM0AskizA         Romano's Macaroni Grill
# 24  4iRzR7OaS-QaSXuvYxEGKA                       Super Dog
# 27  tMkwHmWFUEXrC9ZduonpTg              The Green Pheasant
# 28  QdN72BWoyFypdGJhhI5r7g                         Bar One
# ...

# %%
df.info()
df.to_csv('/Users/garrettpinkston/TIM147/Project/data/restaurantsOnly.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52268 entries, 3 to 150340
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   business_id    52268 non-null  object
#  1   name           52268 non-null  object
#  2   address        52268 non-null  object
#  3   city           52268 non-null  object
#  4   state          52268 non-null  object
#  5   postal_code    52268 non-null  object
#  6   latitude       52268 non-null  float64
#  7   longitude      52268 non-null  float64
#  8   stars          52268 non-null  float64
#  9   review_count   52268 non-null  int64
#  10  is_open        52268 non-null  int64
#  11  attributes     51703 non-null  object
#  12  categories     52268 non-null  object
#  13  hours          44990 non-null  object
#  14  is_restaurant  52268 non-null  object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 6.4+ MB

# %%
df2 = pd.read_json('/Users/garrettpinkston/TIM147/Project/data/xaa.json',lines=True)
print(df2.info())
df2['Match'] = df2['business_id'].isin(df['business_id'].tolist())
df2 = df2[df2['Match']==True]
df2 = df2.drop('Match',axis=1)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1404895 entries, 0 to 1404894
# Data columns (total 9 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   review_id    1404895 non-null  object
#  1   user_id      1404895 non-null  object
#  2   business_id  1404895 non-null  object
#  3   stars        1404895 non-null  int64
#  4   useful       1404895 non-null  int64
#  5   funny        1404895 non-null  int64
#  6   cool         1404895 non-null  int64
#  7   text         1404895 non-null  object
#  8   date         1404895 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 96.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 952267 entries, 0 to 1404894
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   review_id    952267 non-null  object
#  1   user_id      952267 non-null  object
# ...

# %%
df2.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# 5  JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 2      3       0      0     0
# 3      5       1      0     1
# 4      4       1      0     1
# 5      1       1      2     1
#
#                                                 text                date
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 2  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03
# ...

# %%
df3 = pd.read_json('/Users/garrettpinkston/TIM147/Project/data/xab.json',lines=True)
print(df3.info())
df3['Match'] = df3['business_id'].isin(df['business_id'].tolist())
df3 = df3[df3['Match']==True]
df3 = df3.drop('Match',axis=1)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1403791 entries, 0 to 1403790
# Data columns (total 9 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   review_id    1403791 non-null  object
#  1   user_id      1403791 non-null  object
#  2   business_id  1403791 non-null  object
#  3   stars        1403791 non-null  int64
#  4   useful       1403791 non-null  int64
#  5   funny        1403791 non-null  int64
#  6   cool         1403791 non-null  int64
#  7   text         1403791 non-null  object
#  8   date         1403791 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 96.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 947398 entries, 0 to 1403788
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   review_id    947398 non-null  object
#  1   user_id      947398 non-null  object
# ...

# %%
simpleDf1 = pd.concat([df2, df3], ignore_index=True, sort=False)

# %%
simpleDf1.to_csv('/Users/garrettpinkston/TIM147/Project/data/simpleDf1.csv')

# %%
simpleDf1 = pd.read_csv('/Users/garrettpinkston/TIM147/Project/data/simpleDf1.csv')

# %%
df2 = pd.read_json('/Users/garrettpinkston/TIM147/Project/data/xac.json',lines=True)
print(df2.info())
df2['Match'] = df2['business_id'].isin(df['business_id'].tolist())
df2 = df2[df2['Match']==True]
df2 = df2.drop('Match',axis=1)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1403553 entries, 0 to 1403552
# Data columns (total 9 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   review_id    1403553 non-null  object
#  1   user_id      1403553 non-null  object
#  2   business_id  1403553 non-null  object
#  3   stars        1403553 non-null  int64
#  4   useful       1403553 non-null  int64
#  5   funny        1403553 non-null  int64
#  6   cool         1403553 non-null  int64
#  7   text         1403553 non-null  object
#  8   date         1403553 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 96.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 937438 entries, 2 to 1403549
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   review_id    937438 non-null  object
#  1   user_id      937438 non-null  object
# ...

# %%
df3 = pd.read_json('/Users/garrettpinkston/TIM147/Project/data/xad.json',lines=True)
print(df3.info())
df3['Match'] = df3['business_id'].isin(df['business_id'].tolist())
df3 = df3[df3['Match']==True]
df3 = df3.drop('Match',axis=1)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1406093 entries, 0 to 1406092
# Data columns (total 9 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   review_id    1406093 non-null  object
#  1   user_id      1406093 non-null  object
#  2   business_id  1406093 non-null  object
#  3   stars        1406093 non-null  int64
#  4   useful       1406093 non-null  int64
#  5   funny        1406093 non-null  int64
#  6   cool         1406093 non-null  int64
#  7   text         1406093 non-null  object
#  8   date         1406093 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 96.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 955850 entries, 0 to 1406092
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   review_id    955850 non-null  object
#  1   user_id      955850 non-null  object
# ...

# %%
simpleDf2 = pd.concat([df2, df3], ignore_index=True, sort=False)
simpleDf2.to_csv('/Users/garrettpinkston/TIM147/Project/data/simpleDf2.csv')

# %%
simpleDf2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1893288 entries, 0 to 1893287
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   review_id    object
#  1   user_id      object
#  2   business_id  object
#  3   stars        int64
#  4   useful       int64
#  5   funny        int64
#  6   cool         int64
#  7   text         object
#  8   date         datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 130.0+ MB

# %%
simpleDf3 = pd.read_csv('/Users/garrettpinkston/TIM147/Project/data/simpleDf2.csv')

# %%
df3 = pd.read_json('/Users/garrettpinkston/TIM147/Project/data/xae.json',lines=True)
print(df3.info())
df3['Match'] = df3['business_id'].isin(df['business_id'].tolist())
df3 = df3[df3['Match']==True]
df3 = df3.drop('Match',axis=1)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 905400 entries, 0 to 905399
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   review_id    905400 non-null  object
#  1   user_id      905400 non-null  object
#  2   business_id  905400 non-null  object
#  3   stars        905400 non-null  int64
#  4   useful       905400 non-null  int64
#  5   funny        905400 non-null  int64
#  6   cool         905400 non-null  int64
#  7   text         905400 non-null  object
#  8   date         905400 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 62.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 626552 entries, 0 to 905399
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   review_id    626552 non-null  object
#  1   user_id      626552 non-null  object
# ...

# %%
simpleDf3 = pd.concat([simpleDf3, df3], ignore_index=True, sort=False)

# %%
simpleDf3.to_csv('/Users/garrettpinkston/TIM147/Project/data/simpleDf2.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/jh/31bd5yy15gg_f8m1xz8qn8qc0000gn/T/ipykernel_33492/6567314.py in <module>
# ----> 1 simpleDf3.to_csv('/Users/garrettpinkston/TIM147/Project/data/simpleDf2.csv',lines=True)
#
# TypeError: to_csv() got an unexpected keyword argument 'lines'

# %%
rdf = pd.read_json('/Users/garrettpinkston/TIM147/Project/data/Original/yelp_academic_dataset_checkin.json',lines=True)

# %%
rdf['dates'] = rdf['date'].str.split(", ").tolist()
rdf = rdf.drop('date',axis=1)

rdf
# Out:
#                    business_id  \
# 0       ---kPU91CF4Lq2-WlRu9Lw
# 1       --0iUa4sNDFiZFrAdIWhZQ
# 2       --30_8IhuyMHbSOcNWd6DQ
# 3       --7PUidqRWpRSpXebiyxTg
# 4       --7jw19RH9JKXgFohspgQw
# ...                        ...
# 131925  zznJox6-nmXlGYNWgTDwQQ
# 131926  zznZqH9CiAznbkV6fXyHWA
# 131927  zzu6_r3DxBJuXcjnOYVdTw
# 131928  zzw66H6hVjXQEt0Js3Mo4A
# 131929  zzyx5x0Z7xXWWvWnZFuxlQ
#
#                                                     dates
# 0       [2020-03-13 21:10:56, 2020-06-02 22:18:06, 202...
# 1       [2010-09-13 21:43:09, 2011-05-04 23:08:15, 201...
# 2              [2013-06-14 23:29:17, 2014-08-13 23:20:22]
# 3       [2011-02-15 17:12:00, 2011-07-28 02:46:10, 201...
# 4       [2014-04-21 20:42:11, 2014-04-28 21:04:46, 201...
# ...                                                   ...
# 131925  [2013-03-23 16:22:47, 2013-04-07 02:03:12, 201...
# 131926                              [2021-06-12 01:16:12]
# ...

# %%
rdf['Match'] = rdf['business_id'].isin(df['business_id'].tolist())
rdf.info()
rdf = rdf[rdf['Match']==True]
rdf = rdf.drop('Match',axis=1)
rdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131930 entries, 0 to 131929
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   business_id  131930 non-null  object
#  1   dates        131930 non-null  object
#  2   Match        131930 non-null  bool
# dtypes: bool(1), object(2)
# memory usage: 2.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51302 entries, 0 to 131929
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   business_id  51302 non-null  object
#  1   dates        51302 non-null  object
# dtypes: object(2)
# memory usage: 1.2+ MB

# %%
restaurantsWithReviews = df.merge(rdf,on='business_id')

# %%
rdf.to_csv('/Users/garrettpinkston/TIM147/Project/data/ReviewTimestamp.csv')

# %%
rdf
# Out:
#                    business_id  \
# 0       ---kPU91CF4Lq2-WlRu9Lw
# 1       --0iUa4sNDFiZFrAdIWhZQ
# 3       --7PUidqRWpRSpXebiyxTg
# 5       --8IbOsAAxjKRoYsBFL-PA
# 18      --ZVrH2X2QXBFdCilbirsw
# ...                        ...
# 131924  zzjFdJwXuxBOGe9JeY_EMw
# 131925  zznJox6-nmXlGYNWgTDwQQ
# 131926  zznZqH9CiAznbkV6fXyHWA
# 131927  zzu6_r3DxBJuXcjnOYVdTw
# 131929  zzyx5x0Z7xXWWvWnZFuxlQ
#
#                                                     dates
# 0       [2020-03-13 21:10:56, 2020-06-02 22:18:06, 202...
# 1       [2010-09-13 21:43:09, 2011-05-04 23:08:15, 201...
# 3       [2011-02-15 17:12:00, 2011-07-28 02:46:10, 201...
# 5       [2015-06-06 01:03:19, 2015-07-29 16:50:58, 201...
# 18      [2010-08-12 18:21:29, 2010-08-20 17:49:17, 201...
# ...                                                   ...
# 131924  [2015-01-14 19:21:48, 2015-06-26 17:16:54, 201...
# 131925  [2013-03-23 16:22:47, 2013-04-07 02:03:12, 201...
# ...

# %%
restaurantsWithReviews.to_csv('/Users/garrettpinkston/TIM147/Project/data/RestaurantsWithDates.csv')

# %%
restaurantsWithReviews
# Out:
#                   business_id                           name  \
# 0      MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 1      CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 2      k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 3      bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 4      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# ...                       ...                            ...
# 51297  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 51298  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 51299  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 51300  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
# 51301  hn9Toz3s-Ei3uZPt7esExA          West Side Kebab House
#
#                      address             city state postal_code   latitude  \
# 0                935 Race St     Philadelphia    PA       19107  39.955505
# 1              615 S Main St     Ashland City    TN       37015  36.269593
# ...

# %%
snippet = restaurantsWithReviews.iloc[0:30]

# %%
snippet.to_csv('/Users/garrettpinkston/TIM147/Project/data/FormattedRestaurantSnippet.csv')

# %%
snippet
# Out:
#                business_id                                 name  \
# 0   MTSW4McQd7CbVtyjqoe9mw                   St Honore Pastries
# 1   CF33F8-E6oudUQ46HnavjQ                       Sonic Drive-In
# 2   k0hlBqXX-Bt0vf1op7Jr1w                Tsevi's Pub And Grill
# 3   bBDDEgkFA1Otx9Lfe7BZUQ                       Sonic Drive-In
# 4   eEOYSgkmpB90uNA7lDOMRA                Vietnamese Food Truck
# 5   il_Ro8jwPlHresjw9EGmBg                              Denny's
# 6   0bPLkL0QhhPO5kt1_EXmNQ                 Zio's Italian Market
# 7   MUTTqe8uqyMdBl186RmNeA                             Tuna Bar
# 8   ROeacJQwBeh05Rqg7F6TCg                                  BAP
# 9   WKMJwqnfZKsAae75RMP6jA       Roast Coffeehouse and Wine Bar
# 10  kfNv-JZpuN6TVNSO6hHdkw                      Hibachi Express
# 11  9OG5YkX1g2GReZM0AskizA              Romano's Macaroni Grill
# 12  4iRzR7OaS-QaSXuvYxEGKA                            Super Dog
# 13  tMkwHmWFUEXrC9ZduonpTg                   The Green Pheasant
# ...
